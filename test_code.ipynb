# %%
print('a')
# Out:
# a

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/commit_Tving/Tving_overseas_expansion_project'
# Out:
# /content/drive/MyDrive/commit_Tving/Tving_overseas_expansion_project

# %%
# !git config --global user.email 'san8846@naver.com'
# !git config --global user.name 'JHyoG'

# %%
# 원하는 폴더만 commit
# !git add test_code.ipynb

# 폴더 내에 모든 파일을 commit
#!git add --all

# %%
# !git commit -m 'push로 github에 첫번쨰로 보내는 코드'

# !git remote add origin https://{oauth2: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@github.com/JHyoG/repository.git
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# remote: Repository not found.
# fatal: repository 'https://github.com/JHyoG/repository.git/' not found
